# %%
# import pandas as pd
# import os
# from google.colab import drive
# try:
#     #load the datasets from drive
#     drive.mount("/content/drive")
#     dataset_path = "/content/drive/My Drive/ai221_project_datasets/"
# except:
#     #If you can't access the dataset via GDrive, upload the files manually.
#     dataset_path = "/ai221_project_datasets/"

from google.colab import drive
import pandas as pd
import os

drive.mount('/content/drive')
dataset_path = '/content/drive/My Drive/MEngAI/AI 221/Datasets/Food Prices/'
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
print(os.listdir(dataset_path))
#Change the path and filenames as needed.
#Note: update to latest datasets before presentation

#World Food Program dataset
df_wfp = pd.read_csv(dataset_path+"wfp_food_prices_phl.csv") #Food prices
df_wfp_qc = pd.read_csv(dataset_path+"wfp_food_prices_phl_qc.csv") #QuickCharts Food prices

#World Bank dataset
df_wb = pd.read_csv(dataset_path+"PHL_RTFP_mkt_2007_2024-06-04.csv") #Food prices
df_wb_x = pd.read_csv(dataset_path+"PHL_RTP_ticker_info_2007_2024-06-04.csv") #Forex, use to get USD values
# Out:
# ['PHL_RTP_ticker_info_2007_2024-06-04.csv', 'PHL_RTFP_mkt_2007_2024-06-04.csv', 'PHL_RTP_details_2007_2024-06-04.csv', 'wfp_food_prices_phl_qc.csv', 'wfp_food_prices_phl.csv']
# <ipython-input-10-4bc6b87b0f70>:6: DtypeWarning: Columns (4,5,12,13) have mixed types. Specify dtype option on import or set low_memory=False.
#   df_wfp = pd.read_csv(dataset_path+"wfp_food_prices_phl.csv") #Food prices

# %%
df_wfp.head()
# Out:
#          date                   admin1               admin2            market  \
# 0       #date               #adm1+name           #adm2+name  #loc+market+name
# 1  2000-01-15  National Capital region  Metropolitan Manila      Metro Manila
# 2  2000-01-15  National Capital region  Metropolitan Manila      Metro Manila
# 3  2000-01-15  National Capital region  Metropolitan Manila      Metro Manila
# 4  2000-01-15  National Capital region  Metropolitan Manila      Metro Manila
#
#     latitude   longitude            category                commodity  \
# 0   #geo+lat    #geo+lon          #item+type               #item+name
# 1  14.604167  120.982222  cereals and tubers     Maize flour (yellow)
# 2  14.604167  120.982222  cereals and tubers  Rice (milled, superior)
# 3  14.604167  120.982222  cereals and tubers  Rice (milled, superior)
# 4  14.604167  120.982222  cereals and tubers   Rice (regular, milled)
#
#          unit         priceflag         pricetype   currency   price  \
# 0  #item+unit  #item+price+flag  #item+price+type  #currency  #value
# 1          KG            actual            Retail        PHP    15.0
# 2          KG            actual            Retail        PHP    20.0
# 3          KG            actual         Wholesale        PHP   18.35
# 4          KG            actual            Retail        PHP    18.0
#
#      usdprice
# 0  #value+usd
# 1      0.3717
# 2      0.4957
# 3      0.4548
# 4      0.4461

# %%
df_wfp_qc.head()
# Out:
#          date                                               code    usdprice
# 0       #date                                         #meta+code  #value+usd
# 1  2000-01-15  Region XI-Davao del Sur-Davao City-Rice (regul...       0.399
# 2  2000-02-15  Region XI-Davao del Sur-Davao City-Rice (regul...      0.4143
# 3  2000-03-15  Region XI-Davao del Sur-Davao City-Rice (regul...      0.4156
# 4  2000-04-15  Region XI-Davao del Sur-Davao City-Rice (regul...      0.4129

# %%
df_wb.head()
# Out:
#   ISO3      country                         adm1_name adm2_name mkt_name  \
# 0  PHL  Philippines  Cordillera Administrative region      Abra     Abra
# 1  PHL  Philippines  Cordillera Administrative region      Abra     Abra
# 2  PHL  Philippines  Cordillera Administrative region      Abra     Abra
# 3  PHL  Philippines  Cordillera Administrative region      Abra     Abra
# 4  PHL  Philippines  Cordillera Administrative region      Abra     Abra
#
#          lat         lon                   geo_id  price_date  year  ...  \
# 0  17.600651  120.619362  gid_1760065101206193620  2007-01-01  2007  ...
# 1  17.600651  120.619362  gid_1760065101206193620  2007-02-01  2007  ...
# 2  17.600651  120.619362  gid_1760065101206193620  2007-03-01  2007  ...
# 3  17.600651  120.619362  gid_1760065101206193620  2007-04-01  2007  ...
# 4  17.600651  120.619362  gid_1760065101206193620  2007-05-01  2007  ...
#
#    l_tomatoes c_tomatoes inflation_tomatoes trust_tomatoes o_food_price_index  \
# 0       30.80      38.02                NaN            7.3               0.72
# 1       32.22      36.56                NaN            7.3               0.72
# 2       30.21      34.14                NaN            7.3               0.70
# 3       29.09      36.51                NaN            7.3               0.70
# 4       33.22      38.69                NaN            7.3               0.71
#
#    h_food_price_index  l_food_price_index  c_food_price_index  \
# 0                0.73                0.71                0.72
# 1                0.73                0.70                0.70
# 2                0.71                0.69                0.70
# 3                0.71                0.69                0.71
# 4                0.73                0.70                0.71
#
#    inflation_food_price_index  trust_food_price_index
# 0                         NaN                     9.6
# 1                         NaN                     9.6
# 2                         NaN                     9.6
# 3                         NaN                     9.6
# 4                         NaN                     9.6
#
# [5 rows x 109 columns]

# %%
df_wb_x.head()
# Out:
#   iso3      country                    ticker  \
# 0  PHL  Philippines                     beans
# 1  PHL  Philippines                   cabbage
# 2  PHL  Philippines                   carrots
# 3  PHL  Philippines                      eggs
# 4  PHL  Philippines  exchange_rate_unofficial
#
#                                            full_name    units  \
# 0                                       Beans (mung)       KG
# 1                                            Cabbage       KG
# 2                                            Carrots       KG
# 3                                               Eggs     Unit
# 4  Unofficial exchange rate (Parallel-market Esti...  USD/LCU
#
#   food_index_weight data_coverage  r2_imputation
# 0                 1        15.06%           0.88
# 1                 1         23.6%           0.93
# 2                 1        24.39%           0.93
# 3                12        21.41%           0.99
# 4                 0          100%            NaN

# %% [markdown]
# Part 1: Data Preprocessing and Visualization

# %% [markdown]
# Part 2: Clustering + GP to determine highest impact food prices

# %% [markdown]
# Part 3: Extrapolation of highest impact curves pre-2020
